# %% [markdown]
# <a href="https://colab.research.google.com/github/farrelrassya/teachingMLDL/blob/main/01.%20Machine%20Learning/08.%20Week%208/Datasets/Untitled64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load file .txt ke pandas
df = pd.read_csv('YearPredictionMSD.txt', sep=',', header=None)

# Simpan ke .csv
df.to_csv('RegresiUTSTelkom.csv', index=False, header=False)

# %%
df = pd.read_csv('YearPredictionMSD.csv', sep=',', header=None)
df.head(5)
# Out:
#      0         1         2         3         4         5         6         7   \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#          8         9   ...        81         82        83        84        85  \
# 0 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344   1.11144
# 1  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 2  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 3 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 4  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
#
# ...

# %%
df.rename(columns={0: 'Target'}, inplace=True)
df.head(5)
# Out:
#    Target         1         2         3         4         5         6  \
# 0    2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1    2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2    2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3    2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4    2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
#
#           7         8         9  ...        81         82        83        84  \
# 0 -25.01202 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344
# 1   8.76630  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836
# 2  -3.27872  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792
# 3   5.05097 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617
# 4 -12.48207  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522
#
#          85        86         87        88         89        90
# ...

# %%
df.to_csv('RegresiUTSTelkom.csv', index=False, header=False)

# %%
df = pd.read_csv('RegresiUTSTelkom.csv', sep=',', header=None)
df.head(5)
# Out:
#      0         1         2         3         4         5         6         7   \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#          8         9   ...        81         82        83        84        85  \
# 0 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344   1.11144
# 1  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 2  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 3 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 4  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
#
# ...

# %%
df.describe()
# Out:
#                   0              1              2              3   \
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean     1998.397082      43.387126       1.289554       8.658347
# std        10.931046       6.067558      51.580351      35.268585
# min      1922.000000       1.749000    -337.092500    -301.005060
# 25%      1994.000000      39.954690     -26.059520     -11.462710
# 50%      2002.000000      44.258500       8.417850      10.476320
# 75%      2006.000000      47.833890      36.124010      29.764820
# max      2011.000000      61.970140     384.065730     322.851430
#
#                   4              5              6              7   \
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean        1.164124      -6.553601      -9.521975      -2.391089
# std        16.322790      22.860785      12.857751      14.571873
# min      -154.183580    -181.953370     -81.794290    -188.214000
# ...

# %%
df
# Out:
#           0         1         2         3         4         5         6   \
# 0       2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1       2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2       2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3       2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4       2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
# ...      ...       ...       ...       ...       ...       ...       ...
# 515340  2006  51.28467  45.88068  22.19582  -5.53319  -3.61835 -16.36914
# 515341  2006  49.87870  37.93125  18.65987  -3.63581 -27.75665 -18.52988
# 515342  2006  45.12852  12.65758 -38.72018   8.80882 -29.29985  -2.28706
# 515343  2006  44.16614  32.38368  -3.34971  -2.49165 -19.59278 -18.67098
# 515344  2005  51.85726  59.11655  26.39436  -5.46030 -20.69012 -19.95528
#
#               7         8         9   ...        81         82         83  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515345 entries, 0 to 515344
# Data columns (total 91 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       515345 non-null  int64
#  1   1       515345 non-null  float64
#  2   2       515345 non-null  float64
#  3   3       515345 non-null  float64
#  4   4       515345 non-null  float64
#  5   5       515345 non-null  float64
#  6   6       515345 non-null  float64
#  7   7       515345 non-null  float64
#  8   8       515345 non-null  float64
#  9   9       515345 non-null  float64
#  10  10      515345 non-null  float64
#  11  11      515345 non-null  float64
#  12  12      515345 non-null  float64
#  13  13      515345 non-null  float64
#  14  14      515345 non-null  float64
#  15  15      515345 non-null  float64
#  16  16      515345 non-null  float64
#  17  17      515345 non-null  float64
#  18  18      515345 non-null  float64
#  19  19      515345 non-null  float64
# ...

# %%
df.to_csv('RegresiUTSTelkom.csv', index=False, header=False)
